# %% [markdown]
# <a href="https://colab.research.google.com/github/princeatul/fastai_course/blob/master/Lesson_1_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
#bs = 16

# %%
path = untar_data(URLs.PETS);
path
# Out:
# ...
# PosixPath('/root/.fastai/data/oxford-iiit-pet')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Persian_259.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_66.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_21.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/shiba_inu_156.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_98.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 61

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.400109</td>
#       <td>0.339845</td>
#       <td>0.106901</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.594361</td>
#       <td>0.275913</td>
#       <td>0.087957</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.379409</td>
#       <td>0.232071</td>
#       <td>0.069689</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.272387</td>
#       <td>0.221091</td>
#       <td>0.071042</td>
#       <td>01:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses, idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Birman', 'Ragdoll', 6),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 5),
#  ('Ragdoll', 'Birman', 4),
#  ('chihuahua', 'miniature_pinscher', 4),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('basset_hound', 'beagle', 3),
#  ('english_setter', 'english_cocker_spaniel', 3),
#  ('staffordshire_bull_terrier', 'american_bulldog', 3),
#  ('Bengal', 'Egyptian_Mau', 2),
#  ('Birman', 'Siamese', 2),
#  ('Persian', 'Ragdoll', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('Siamese', 'Birman', 2),
#  ('Siamese', 'Bombay', 2),
#  ('american_bulldog', 'boxer', 2),
#  ('american_bulldog', 'staffordshire_bull_terrier', 2),
#  ('american_pit_bull_terrier', 'american_bulldog', 2),
#  ('basset_hound', 'english_cocker_spaniel', 2),
#  ('boxer', 'american_bulldog', 2),
#  ('havanese', 'yorkshire_terrier', 2),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 2)]

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.672824</td>
#       <td>0.334575</td>
#       <td>0.105548</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.233100</td>
#       <td>0.211237</td>
#       <td>0.069012</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.216781</td>
#       <td>0.207538</td>
#       <td>0.064953</td>
#       <td>01:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(),
                                   size=299, bs=bs//2).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.712684</td>
#       <td>0.326669</td>
#       <td>0.103518</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.512778</td>
#       <td>0.330186</td>
#       <td>0.101489</td>
#       <td>02:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.435003</td>
#       <td>0.233677</td>
#       <td>0.079161</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.351984</td>
#       <td>0.228552</td>
#       <td>0.069689</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.287709</td>
#       <td>0.200470</td>
#       <td>0.056834</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1-50')
